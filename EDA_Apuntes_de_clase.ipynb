# %% [markdown]
# <a href="https://colab.research.google.com/github/IVANV341/Curso-inteligencia-artificial/blob/main/EDA_Apuntes_de_clase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EDA ( ANALISIS EXPLORATORIO DE LOS DATOS) INTRODUCCION "EXPLORATORY DATA ANALYSIS"
# Ejemplo:

# %% [markdown]
# Importar librerias (Tienen que estar en la primera celda)

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- ------------------
# absl-py                            1.4.0
# accelerate                         1.3.0
# aiohappyeyeballs                   2.4.4
# aiohttp                            3.11.12
# aiosignal                          1.3.2
# alabaster                          1.0.0
# albucore                           0.0.23
# albumentations                     2.0.3
# ale-py                             0.10.1
# altair                             5.5.0
# annotated-types                    0.7.0
# anyio                              3.7.1
# argon2-cffi                        23.1.0
# argon2-cffi-bindings               21.2.0
# array_record                       0.6.0
# arviz                              0.20.0
# astropy                            7.0.0
# astropy-iers-data                  0.2025.2.3.0.32.42
# astunparse                         1.6.3
# atpublic                           4.1.0
# ...

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
https://raw.githubusercontent.com/adicta/bigdata/refs/heads/master/vivienda_clasif.ClassVar
# Out:
#   File "<ipython-input-8-adc26955cb2d>", line 1
#     https://raw.githubusercontent.com/adicta/bigdata/refs/heads/master/vivienda_clasif.ClassVar
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ![CHEAT SHEET NUMPY.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Poner solo el df muestra los primeros 5 y los ultimos 5 datos.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd
import numpy as np


df=pd.read_csv('https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/vivienda_clasif.csv')

# %%
df_local=pd.read_csv('vivienda_clasif.csv')

# %%
df_github=pd.read_csv('https://raw.githubusercontent.com/adiacla/bigdata/refs/heads/master/vivienda_clasif.csv')

# %%
df
# Out:
#      Habitaciones  Area_parqeo  Area_total  Valor_Miles  Clasificacion
# 0               4         4.98         153       504000              2
# 1               4         9.14         178       453600              2
# 2               5         4.03         178       728700              3
# 3               4         2.94         187       701400              3
# 4               5         5.33         187       760200              2
# ..            ...          ...         ...          ...            ...
# 484             4         9.67         210       470400              2
# 485             4         9.08         210       432600              2
# 486             4         5.64         210       501900              2
# 487             4         6.48         210       462000              2
# 488             4         7.88         210       249900              1
#
# [489 rows x 5 columns]

# %%
df.tail()
# Out:
#      Habitaciones  Area_parqeo  Area_total  Valor_Miles  Clasificacion
# 484             4         9.67         210       470400              2
# 485             4         9.08         210       432600              2
# 486             4         5.64         210       501900              2
# 487             4         6.48         210       462000              2
# 488             4         7.88         210       249900              1

# %%
df.shape
# Out:
# (489, 5)

# %%
df
# Out:
#      Habitaciones  Area_parqeo  Area_total  Valor_Miles  Clasificacion
# 0               4         4.98         153       504000              2
# 1               4         9.14         178       453600              2
# 2               5         4.03         178       728700              3
# 3               4         2.94         187       701400              3
# 4               5         5.33         187       760200              2
# ..            ...          ...         ...          ...            ...
# 484             4         9.67         210       470400              2
# 485             4         9.08         210       432600              2
# 486             4         5.64         210       501900              2
# 487             4         6.48         210       462000              2
# 488             4         7.88         210       249900              1
#
# [489 rows x 5 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %%
df.head(10)
# Out:
#    Habitaciones  Area_parqeo  Area_total  Valor_Miles  Clasificacion
# 0             4         4.98         153       504000              2
# 1             4         9.14         178       453600              2
# 2             5         4.03         178       728700              3
# 3             4         2.94         187       701400              3
# 4             5         5.33         187       760200              2
# 5             4         5.21         187       602700              3
# 6             4        12.43         152       480900              2
# 7             4        19.15         152       569100              3
# 8             3        29.93         152       346500              1
# 9             4        17.10         152       396900              2
